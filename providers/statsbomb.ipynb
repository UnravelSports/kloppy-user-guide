# %% [markdown]
# # Statsbomb

# %% [markdown]
# ## Load local files

# %%
from kloppy import statsbomb

dataset = statsbomb.load(
    event_data="../../kloppy/tests/files/statsbomb_3788741_event.json",
    lineup_data="../../kloppy/tests/files/statsbomb_3788741_lineup.json",
    
    # 360 file is optional
    three_sixty_data="../../kloppy/tests/files/statsbomb_3788741_360.json",
    
    # Optional arguments
    coordinates="statsbomb",
    event_types=["pass", "shot"]
)

dataset.to_df().head()
# Out:
#                                event_id event_type    result success  \
# 0  bbc398f7-c784-4958-a504-37b583caf97a       PASS  COMPLETE    True
# 1  5c210f79-9714-44a6-b2ec-387f6a117b37       PASS  COMPLETE    True
# 2  8a3e6668-9680-4417-987e-8db0c6ce6a8b       PASS  COMPLETE    True
# 3  f8e61bb0-b618-4695-9ff9-eaa0584bdbfa       PASS  COMPLETE    True
# 4  1d72ce76-31fd-43e0-a6b2-1f78c8a57a77       PASS  COMPLETE    True
#
#    period_id  timestamp  end_timestamp ball_state ball_owning_team team_id  \
# 0          1      0.878       2.788504      alive              909     909
# 1          1      4.288       6.764772      alive              909     909
# 2          1     12.163      14.093230      alive              914     914
# 3          1     16.420      18.242108      alive              914     914
# 4          1     20.025      21.071484      alive              914     914
#
#   player_id  coordinates_x  coordinates_y  end_coordinates_x  \
# 0     11086          59.95          39.95              32.45
# 1      8963          36.15          30.35              70.65
# 2      8286          43.05           0.05              15.75
# 3      6954           3.25          12.65               7.85
# 4      7036           9.05          38.85              19.65
#
#    end_coordinates_y receiver_player_id set_piece_type body_part_type  \
# 0              28.75               8963       KICK_OFF     RIGHT_FOOT
# 1              75.75               8541            NaN      LEFT_FOOT
# 2               7.45               6954       THROW_IN            NaN
# 3              36.15               7036            NaN     RIGHT_FOOT
# 4              47.85               7173            NaN     RIGHT_FOOT
#
#    pass_type
# 0        NaN
# 1  LONG_BALL
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# ## Load remote files
#
# You can also directly read files from urls (http or https) by passing a url instead of a local path.

# %%
from kloppy import statsbomb

dataset = statsbomb.load(
    event_data="https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/15946.json",
    lineup_data="https://raw.githubusercontent.com/statsbomb/open-data/master/data/lineups/15946.json",
    
    # Optional arguments
    coordinates="statsbomb",
    event_types=["pass", "shot"]
)

dataset.to_df().head()
# Out:
#                                event_id event_type      result success  \
# 0  34208ade-2af4-45c3-970e-655937cad938       PASS    COMPLETE    True
# 1  d1cccb73-c7ef-4b02-8267-ebd7f149904b       PASS  INCOMPLETE   False
# 2  f1cc47d6-4b19-45a6-beb9-33d67fc83f4b       PASS    COMPLETE    True
# 3  f774571f-4b65-43a0-9bfc-6384948d1b82       PASS    COMPLETE    True
# 4  46f0e871-3e72-4817-9a53-af27583ba6c1       PASS    COMPLETE    True
#
#    period_id  timestamp  end_timestamp ball_state ball_owning_team team_id  \
# 0          1      0.098          2.007      alive              206     206
# 1          1      3.497          6.785      alive              206     206
# 2          1      6.785          8.431      alive              217     217
# 3          1      8.431          9.576      alive              217     217
# 4          1     10.433         11.150      alive              217     217
#
#   player_id  coordinates_x  coordinates_y  end_coordinates_x  \
# 0      6581           60.5           40.5               35.5
# 1      6855           35.5           28.5               85.5
# 2      5203           34.5            7.5               34.5
# 3      5470           35.5           20.5               35.5
# 4      5477           33.5            2.5               25.5
#
#    end_coordinates_y receiver_player_id set_piece_type body_part_type  \
# 0               25.5               6855       KICK_OFF      LEFT_FOOT
# 1               72.5               None            NaN     RIGHT_FOOT
# 2               20.5               5470            NaN           HEAD
# 3                1.5               5477            NaN           HEAD
# 4                1.5               5211            NaN     RIGHT_FOOT
#
#    pass_type
# 0        NaN
# 1  LONG_BALL
# 2  HEAD_PASS
# 3  HEAD_PASS
# 4        NaN

# %% [markdown]
# ## Load open data
#
# For loading Statsbomb open data you can also use `statsbomb.load_open_data`. The api is very simular but you don't have to pass the urls.
#
# To uncover the vast amount of open data provided by StatsBomb, you can use `statsbomb.list_open_data`. This functionality relies on `statsbombpy`, so make sure to install it.

# %%
from kloppy import statsbomb

statsbomb.list_open_data()
# Out:
# /Users/jbekkers/PycharmProjects/kloppy-user-guide/.venv/lib/python3.11/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#       match_id  match_date      kick_off                        competition  \
# 0      3895302  2024-04-14  17:30:00.000            Germany - 1. Bundesliga
# 1      3895292  2024-04-06  15:30:00.000            Germany - 1. Bundesliga
# 2      3895333  2024-05-05  18:30:00.000            Germany - 1. Bundesliga
# 3      3895340  2024-05-12  20:30:00.000            Germany - 1. Bundesliga
# 4      3895348  2024-05-18  16:30:00.000            Germany - 1. Bundesliga
# ...        ...         ...           ...                                ...
# 3428     69199  2019-06-27  21:00:00.000  International - Women's World Cup
# 3429     69258  2019-07-02  21:00:00.000  International - Women's World Cup
# 3430     69284  2019-07-03  21:00:00.000  International - Women's World Cup
# 3431     69205  2019-06-29  15:00:00.000  International - Women's World Cup
# 3432     69161  2019-06-24  18:00:00.000  International - Women's World Cup
#
#          season            home_team              away_team  home_score  \
# 0     2023/2024     Bayer Leverkusen          Werder Bremen           5
# 1     2023/2024         Union Berlin       Bayer Leverkusen           0
# 2     2023/2024  Eintracht Frankfurt       Bayer Leverkusen           1
# 3     2023/2024               Bochum       Bayer Leverkusen           0
# 4     2023/2024     Bayer Leverkusen               Augsburg           2
# ...         ...                  ...                    ...         ...
# 3428       2019       Norway Women's        England Women's           0
# 3429       2019      England Women's  United States Women's           1
# 3430       2019  Netherlands Women's         Sweden Women's           1
# 3431       2019        Italy Women's    Netherlands Women's           0
# 3432       2019        Spain Women's  United States Women's           1
#
#       away_score match_status  ... competition_stage  \
# 0              0    available  ...    Regular Season
# 1              1    available  ...    Regular Season
# 2              5    available  ...    Regular Season
# 3              5    available  ...    Regular Season
# 4              1    available  ...    Regular Season
# ...          ...          ...  ...               ...
# 3428           3    available  ...    Regular Season
# 3429           2    available  ...       Semi-finals
# 3430           0    available  ...       Semi-finals
# 3431           2    available  ...    Regular Season
# 3432           2    available  ...       Round of 16
#
#                              stadium                referee  \
# 0                           BayArena            Harm Osmers
# 1     Stadion An der Alten Försterei         Benjamin Brand
# 2                 Deutsche Bank Park      Christian Dingert
# 3                Vonovia Ruhrstadion         Benjamin Brand
# 4                           BayArena    Matthias Jöllenbeck
# ...                              ...                    ...
# 3428                    Stade Océane  Lucila Venegas Montes
# 3429                Groupama Stadium                    NaN
# 3430                Groupama Stadium  Marie-Soleil Beaudoin
# 3431                Stade du Hainaut      Claudia Umpiérrez
# 3432       Stade Auguste-Delaune II         Katalin Kulcsar
#
#                  home_managers             away_managers data_version  \
# 0          Xabier Alonso Olano                Ole Werner        1.1.0
# 1                Nenad Bjelica       Xabier Alonso Olano        1.1.0
# 2              Dino Toppmöller       Xabier Alonso Olano        1.1.0
# 3               Heiko Butscher       Xabier Alonso Olano        1.1.0
# 4          Xabier Alonso Olano     Jess Christian Thorup        1.1.0
# ...                        ...                       ...          ...
# 3428            Martin Sjögren              Phil Neville        1.1.0
# 3429              Phil Neville             Jillian Ellis        1.1.0
# 3430  Sarina Glotzbach-Wiegman         Peter Gerhardsson        1.1.0
# 3431          Milena Bertolini  Sarina Glotzbach-Wiegman        1.1.0
# 3432               Jorge Vilda             Jillian Ellis        1.1.0
#
#      shot_fidelity_version xy_fidelity_version competition_id season_id
# 0                        2                   2              9       281
# 1                        2                   2              9       281
# 2                        2                   2              9       281
# 3                        2                   2              9       281
# 4                        2                   2              9       281
# ...                    ...                 ...            ...       ...
# 3428                     2                   2             72        30
# 3429                     2                   2             72        30
# 3430                     2                   2             72        30
# 3431                     2                   2             72        30
# 3432                     2                   2             72        30
#
# [3433 rows x 24 columns]

# %% [markdown]
# Now, simply take a match_id from the "match_id" column, and pass it into `statsbomb.load_open_data`.

# %%
from kloppy import statsbomb

dataset = statsbomb.load_open_data(
    match_id=15946,
    
    # Optional arguments
    coordinates="statsbomb",
    event_types=["pass", "shot"]
)

dataset.to_df().head()
# Out:
# /Users/jbekkers/PycharmProjects/kloppy-user-guide/.venv/lib/python3.11/site-packages/kloppy/_providers/statsbomb.py:63: UserWarning:
#
# You are about to use StatsBomb public data.
# By using this data, you are agreeing to the user agreement.
# The user agreement can be found here: https://github.com/statsbomb/open-data/blob/master/LICENSE.pdf
#
#   warnings.warn(
#                                event_id event_type      result success  \
# 0  549567bd-36de-4ac8-b8dc-6b5d3f1e4be8       PASS    COMPLETE    True
# 1  4e4e4cad-9897-43ec-842d-585a4077f6ce       PASS  INCOMPLETE   False
# 2  be27cc25-92b5-4696-b43c-aad957a6119a       PASS    COMPLETE    True
# 3  b33c0b7f-7456-4efe-b43c-5fd7cbd14689       PASS    COMPLETE    True
# 4  c587e5ce-fe6e-4cfb-b510-8a8e193699d3       PASS    COMPLETE    True
#
#    period_id              timestamp          end_timestamp ball_state  \
# 0          1 0 days 00:00:00.575000 0 days 00:00:02.590669      alive
# 1          1 0 days 00:00:03.864000 0 days 00:00:07.151421      alive
# 2          1 0 days 00:00:07.152000 0 days 00:00:08.848529      alive
# 3          1 0 days 00:00:08.848000 0 days 00:00:09.983950      alive
# 4          1 0 days 00:00:10.873000 0 days 00:00:11.630764      alive
#
#   ball_owning_team team_id player_id  coordinates_x  coordinates_y  \
# 0              206     206      6581          60.95          40.05
# 1              206     206      6855          36.75          27.25
# 2              217     217      5203          33.55           5.85
# 3              217     217      5470          35.05          18.25
# 4              217     217      5477          34.25           4.85
#
#    end_coordinates_x  end_coordinates_y receiver_player_id set_piece_type  \
# 0              33.75              27.95               6855       KICK_OFF
# 1              86.45              74.15               None           None
# 2              35.05              18.25               5470           None
# 3              36.15               5.25               5477           None
# 4              25.25               1.55               5211           None
#
#   body_part_type  pass_type is_counter_attack
# 0      LEFT_FOOT       None              None
# 1     RIGHT_FOOT  LONG_BALL              None
# 2           None  HIGH_PASS              None
# 3           HEAD  HEAD_PASS              None
# 4     RIGHT_FOOT       None              None
